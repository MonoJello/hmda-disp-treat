# %%
import pandas as pd
import pickle
from utils import model as mod
# from utils import results as res

# %%
df = pd.read_pickle('../data/03_df_data')
segs = pd.read_pickle('../data/02_df_seg_age')

with open("../data/02_dic_ref_groups.pkl", "rb") as file:
    ref_groups = pickle.load(file)

# %%
df.head()
# Out:
#        loan_type   loan_purpose    preapproval construction_method  \
# 1   Conventional  Home purchase  Not requested          Site built
# 2   Conventional  Home purchase  Not requested          Site built
# 5   Conventional  Home purchase  Not requested          Site built
# 13  Conventional  Home purchase  Not requested          Site built
# 15  Conventional      Refinance  Not requested          Site built
#
#     loan_amount action_taken state_code county_code   census_tract  \
# 1       1205000    Purchased         WA     53033.0  53033032318.0
# 2        925000    Purchased         WA     53011.0  53011040303.0
# 5        905000    Purchased         WA     53011.0  53011040905.0
# 13      1505000    Purchased         CA      6065.0   6065045606.0
# 15      1145000    Purchased         WA     53033.0  53033002700.0
#
#    applicant_ethnicity_1  ... loan_term intro_rate_period balloon_payment  \
# 1    Not Hispanic Latino  ...     360.0               NaN      No balloon
# 2      Info not provided  ...     360.0               NaN      No balloon
# 5    Not Hispanic Latino  ...     360.0               NaN      No balloon
# 13   Not Hispanic Latino  ...     360.0               NaN      No balloon
# 15     Info not provided  ...     360.0              84.0      No balloon
#
#     interest_only_payment property_value  \
# 1       Not interest only      1505000.0
# 2       Not interest only      1035000.0
# 5       Not interest only      1135000.0
# 13      Not interest only      4295000.0
# 15      Not interest only      1725000.0
#
#    manufactured_home_secured_property_type  \
# 1                           Not applicable
# 2                           Not applicable
# 5                           Not applicable
# 13                          Not applicable
# 15                          Not applicable
#
#     manufactured_home_land_property_interest  reg_uw  denied  reg_price
# 1                             Not applicable       0       0          0
# 2                             Not applicable       0       0          0
# 5                             Not applicable       0       0          0
# 13                            Not applicable       0       0          0
# 15                            Not applicable       0       0          0
#
# [5 rows x 33 columns]

# %%
segs
# Out:
#       loan_type        loan_purpose applicant_age_above_62  applied  \
# 0  Conventional  Cash out refinance                     No     6188
# 1  Conventional  Cash out refinance                    Yes     4144
# 2  Conventional    Home improvement                     No     2320
# 3  Conventional    Home improvement                    Yes     1564
# 4  Conventional       Home purchase                     No    33801
# 5  Conventional       Home purchase                    Yes     5125
# 6  Conventional           Refinance                     No     6207
# 7  Conventional           Refinance                    Yes     1565
#
#    event_count  event_rate  mi_rate   mu_rate  mx_rate  crit event  crit count
# 0          817    0.132030    2.875  6.791526    10.24        True        True
# 1          564    0.136100    4.250  6.690581    10.24        True        True
# 2          459    0.197845    4.625  8.058573    10.24        True        True
# 3          255    0.163043    5.125  7.478999     9.74        True        True
# 4         2188    0.064732    1.000  6.359663     9.49        True        True
# 5          402    0.078439    2.375  6.334804     9.24        True        True
# 6          441    0.071049    4.250  6.165486     8.25        True        True
# 7          130    0.083067    4.750  6.219404     7.75        True        True

# %%
testing = segs.columns.tolist()[2]
testing
# Out:
# 'applicant_age_above_62'

# %%
ref_groups
# Out:
# {'applicant_race_1': 'White',
#  'applicant_sex': 'Male',
#  'applicant_age_above_62': 'No'}

# %%
segs.loan_type.unique().tolist()
# Out:
# ['Conventional']

# %% [raw]
#  2   county_code                       7455 non-null   float64
#  3   census_tract                      7455 non-null   float64

# %%
drop_this = [
    'applicant_ethnicity_1',        
    'applicant_race_1',                  
    'applicant_sex', 
    'applicant_age_above_62'
]

# %%
def save_summary(
    summary_out, # summary table
    res, # model summary object
    step, # uw or price
    model, # 0 or 1
    # j, # outerseg
    # i, # inner seg
    # iii # test
):

    import pandas as pd
    
    # making tmp summary table
    tmp = pd.DataFrame(columns = [
        'loan type',
        'loan purpose', # loan purp
        'step', # price or uw
        'model', # 0 or 1
        'protected basis',  # female 
        'metric', # pval, coef, r2 **
        'value' #**
    ])
    
    
    
    # save coef
    tmp2 = pd.DataFrame({
        "metric": 'param',
        "value": [res.params.values[1]],
    })

    tmp = pd.concat([tmp, tmp2], axis=0, ignore_index=True)
    
    # save p value
    tmp2 = pd.DataFrame({
        "metric": 'pval',
        "value": [res.pvalues.values[1]],
    })
    
    tmp = pd.concat([tmp, tmp2], axis=0, ignore_index=True)
    
    
    # save model fit
    
    if step == 'price':
    
    
        # ols
        tmp2 = pd.DataFrame({
            "metric": 'adj R2',
            "value": [res.rsquared_adj],
        })

        tmp = pd.concat([tmp, tmp2], axis=0, ignore_index=True)
        

    elif step == 'uw':

        # logit
        tmp2 = pd.DataFrame({
            "metric": 'psu R2',
            "value": [1 - (res.llf / res.llnull)],
        })

        tmp = pd.concat([tmp, tmp2], axis=0, ignore_index=True)


        
    # save other groups for pivots
    tmp['loan type'] = type_i
    tmp['loan purpose'] = purp_i
    tmp['protected basis'] = group_i
    tmp['step'] = step
    tmp['model'] = model
    
    
    summary_out = pd.concat([summary_out, tmp], axis=0, ignore_index=True)
    
    
    return summary_out

# %%
# %%capture output

reg_summary = pd.DataFrame(columns = [
    'loan type',
    'loan purpose', # loan purp
    'step', # price or uw
    'model', # 0 or 1
    'protected basis',  # female 
    'metric', # pval, coef, r2 **
    'value' #**
])

for type_i in segs.loan_type.unique().tolist():
    print(f'\nType: {type_i}')
    
    for purp_i in segs[segs['loan_type'] == type_i].loan_purpose.unique().tolist():
        print(f'\n Purpose: {purp_i}')

        group_list = segs[(segs['loan_type'] == type_i)&(segs['loan_purpose'] == purp_i)][testing].unique().tolist()
        group_list.remove(ref_groups[testing])
        for group_i in group_list:
            print(f'\n  PB: {group_i}')
            print(f'  Ref: {ref_groups[testing]}')
    
            """
            Underwriting
            """

            print('\nUnderwriting')
    
            df_tmp = df[
                (df.loan_type == type_i) &
                (df.loan_purpose == purp_i) &
                (df[testing].isin([ref_groups[testing]] +  [group_i])) &
                (df['reg_uw'] == 1)
            ]



            
            
            print(f'shape: {df_tmp.shape}')

            print(df_tmp.groupby(testing).agg(
                count=('denied','size'),
                event_count=('denied','sum')
            ))

            # make dummy for protected basis group

            df_tmp[group_i] = (df_tmp[testing] == group_i).astype(int)

            df_tmp.drop(columns = drop_this, inplace = True)
            
            # drop columns with single value. will end up being things like indicator for segment
            df_tmp = df_tmp.loc[:, df_tmp.nunique(dropna=False) > 1]
            

            print('')
            print(df_tmp[group_i].value_counts())
            
            """
            UW Model 0
            """

            print('\nModel 0')
            
            import statsmodels.api as sm
            
            X = sm.add_constant(df_tmp[group_i])
            y = df_tmp["denied"]
            
            
            model = sm.Logit(y, X)
            result = model.fit()
            
            print(result.summary())
    
            reg_summary = save_summary(reg_summary, result, 'uw', 'Model 0')
            
            """
            UW Model 1
            """
            print('\nModel 1')

            result = mod.logistic_woe_run(df_tmp,group_i)

            reg_summary = save_summary(reg_summary, result, 'uw', 'Model 1')
            
            
            """
            UW Model 2
            """
            print('\nModel 2')

            df_tmp_psa = mod.make_match_pair(df_tmp,'denied',group_i)
            
            result = mod.logistic_woe_run(df_tmp_psa,group_i)


            reg_summary = save_summary(reg_summary, result, 'uw', 'Model 2')








            
            
    
            """
            Pricing
            """
            print('\nPricing')
                
            df_tmp = df[
                (df.loan_type == type_i) &
                (df.loan_purpose == purp_i) &
                (df[testing].isin([ref_groups[testing]] +  [group_i])) &
                (df['reg_price'] == 1)
            ]



            
            
            print(f'shape: {df_tmp.shape}')

            # make dummy for protected basis group

            df_tmp[group_i] = (df_tmp[testing] == group_i).astype(int)

            df_tmp.drop(columns = drop_this, inplace = True)
            
            # drop columns with single value. will end up being things like indicator for segment
            df_tmp = df_tmp.loc[:, df_tmp.nunique(dropna=False) > 1]
            

            print('')
            print(df_tmp[group_i].value_counts())
    
            
            """
            Pri Model 0
            """
            print('\nModel 0')
            
            import statsmodels.api as sm
            
            X = sm.add_constant(df_tmp[group_i])
            y = df_tmp["interest_rate"]
            
            
            model = sm.OLS(y, X)
            result = model.fit()
            
            print(result.summary())
            
            reg_summary = save_summary(reg_summary, result, 'price', 'Model 0')
    
    
    
            
            """
            Pri Model 1
            """
            print('\nModel 1')

            result = mod.ols_dummy_run(df_tmp,group_i)

            print(result.summary())
            
            reg_summary = save_summary(reg_summary, result, 'price', 'Model 1')
            
    
            """
            Pri Model 2
            """

            print('\nModel 2')

            #pair function needs to ignore something, gets excluded later bc singular value
            df_tmp['rnd'] = 999
            df_tmp['action_taken'] = 'junk'
            
            df_tmp_psa = mod.make_match_pair(df_tmp,'rnd',group_i)
            result = mod.ols_dummy_run(df_tmp_psa,group_i)

            print(result.summary())
            
            reg_summary = save_summary(reg_summary, result, 'price', 'Model 2')

            
            
    #         break # group_i

    #     break # purp_i
    # break # type_i

# %%
with open(f"../data/regression analysis output {testing}.txt", "w") as f:
    f.write(output.stdout)
    f.write(output.stderr)

# %%
reg_summary.head()
# Out:
#       loan type        loan purpose step    model protected basis  metric  \
# 0  Conventional  Cash out refinance   uw  Model 0             Yes   param
# 1  Conventional  Cash out refinance   uw  Model 0             Yes    pval
# 2  Conventional  Cash out refinance   uw  Model 0             Yes  psu R2
# 3  Conventional  Cash out refinance   uw  Model 1             Yes   param
# 4  Conventional  Cash out refinance   uw  Model 1             Yes    pval
#
#       value
# 0  0.012385
# 1  0.825097
# 2  0.000006
# 3 -0.141946
# 4  0.058106

# %%
reg_summary.to_pickle(f"../data/04_df_reg_{testing}.pkl")
# reg_summary = pd.read_pickle("./data/reg_summary.pkl")

# %%
print(
    'hello'
)
# Out:
# hello
