# %%
import pandas as pd

# %%
df = pd.read_pickle('../data/02_df_data.pkl')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 87692 entries, 1 to 368993
# Data columns (total 89 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   activity_year                             87692 non-null  int64
#  1   lei                                       87692 non-null  str
#  2   loan_type                                 87692 non-null  str
#  3   loan_purpose                              87692 non-null  str
#  4   preapproval                               87692 non-null  str
#  5   construction_method                       87692 non-null  str
#  6   occupancy_type                            87692 non-null  str
#  7   loan_amount                               87692 non-null  int64
#  8   action_taken                              87692 non-null  str
#  9   state_code                                85395 non-null  str
# ...

# %%
df.shape
# Out:
# (87692, 89)

# %% [markdown]
# # empty columns

# %%
df = df.dropna(axis=1, how="all")
df.shape
# Out:
# (87692, 63)

# %% [markdown]
# # single value

# %%
df = df.loc[:, df.nunique(dropna=False) > 1]
df.shape
# Out:
# (87692, 49)

# %% [markdown]
# # dont need

# %% [markdown]
# These are excluded because were using other versions of the column such as age. Some are excluded because they leak information about decisions such as denial reason.

# %%
keep = ['loan_type',
 'loan_purpose',
 'preapproval',
 'construction_method',
 # 'occupancy_type',
 'loan_amount',
 'action_taken',
 'state_code',
 'county_code',
 'census_tract',
 'applicant_ethnicity_1',
 # 'applicant_ethnicity_observed',
 'applicant_race_1',
 # 'applicant_race_observed',
 'applicant_sex',
 # 'applicant_sex_observed',
 # 'applicant_age',
 'applicant_age_above_62',
 'income',
 # 'purchaser_type',
 'rate_spread',
 'hoepa_status',
 'lien_status',
 'applicant_credit_scoring_model',
 # 'co_applicant_credit_scoring_model',
 # 'denial_reason_1',
 'total_loan_costs',
 'total_points_and_fees',
 'origination_charges',
 'discount_points',
 'lender_credits',
 'interest_rate',
 'debt_to_income_ratio',
 'combined_loan_to_value_ratio',
 'loan_term',
 'intro_rate_period',
 'balloon_payment',
 'interest_only_payment',
 'property_value',
 'manufactured_home_secured_property_type',
 'manufactured_home_land_property_interest',
 # 'total_units',
 # 'multifamily_affordable_units', 
 # 'submission_of_application',
 # 'initially_payable_to_institution',
 # 'aus_1',
 # 'open_end_line_of_credit',
 # 'business_or_commercial_purpose',
 'reg_uw',
 'denied',
 'reg_price']

# %%
df = df[keep]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 87692 entries, 1 to 368993
# Data columns (total 37 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   loan_type                                 87692 non-null  str
#  1   loan_purpose                              87692 non-null  str
#  2   preapproval                               87692 non-null  str
#  3   construction_method                       87692 non-null  str
#  4   loan_amount                               87692 non-null  int64
#  5   action_taken                              87692 non-null  str
#  6   state_code                                85395 non-null  str
#  7   county_code                               85395 non-null  str
#  8   census_tract                              85395 non-null  str
#  9   applicant_ethnicity_1                     87692 non-null  str
# ...

# %%
df.to_pickle('../data/03_df_data')
